# %% [markdown]
# # 9 类

# %%
# 创建一个名为Restaurant的类，为其__init__()方法设置两个属性：restaurant_name和cuisine_type。
# 创建一个名为describe_restaurant()的方法和一个名为open_restaurant()的方法，其中前者打印前述两项信息，而后者打印一条消息，指出餐馆正在营业。
class Restaurant:
    def __init__(self, restaurant_name, cuisine_type):
        self.restaurant_name = restaurant_name
        self.cuisine_type = cuisine_type

    def describe_restaurant(self):
        print(f"{self.restaurant_name} {self.cuisine_type}")

    def open_restaurant(self):
        print("Restaurant is opening!")

# %%
restaurant = Restaurant("Fruit store", "pizza")
restaurant.describe_restaurant()
restaurant.open_restaurant()
# Out:
# Fruit store pizza
# Restaurant is opening!

# %%
# 三家餐馆　根据为练习9.1编写的类创建三个实例，并对每个实例调用describe_restaurant()方法。
res1 = Restaurant("Pear store", "fruit")
res2 = Restaurant("Orange store", "fruit")
res3 = Restaurant("Apple store", "fruit")
res1.describe_restaurant()
res2.describe_restaurant()
res3.describe_restaurant()
# Out:
# Pear store fruit
# Orange store fruit
# Apple store fruit

# %%
# 用户　创建一个名为User的类，其中包含属性first_name和last_name，还有用户简介中通常会有的其他几个属性。
# 在类User中定义一个名为describe_user()的方法，用于打印用户信息摘要。
# 再定义一个名为greet_user()的方法，用于向用户发出个性化的问候

class User:
    def __init__(self, first_name, last_name, *other_attrs) -> None:
        self.first_name = first_name
        self.last_name = last_name
        for other_attr in other_attrs:
            self.other_attr = other_attr

    def describe_user(self):
        print(f"{self.first_name} {self.last_name} {self.other_attr}")

    def greet_user(self):
        print(f"Hello {self.first_name} !")

# %%
user1 = User("Alan", "Walker", ["address", "zip_code"])
user1.describe_user()
# Out:
# Alan Walker ['address', 'zip_code']

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

    def get_descriptive_name(self):
        long_name = f"{self.make} {self.model} {self.year}"
        return long_name.title()

    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles in it.")

# %%
my_new_car = Car("audi", "a4", "2014")
print(my_new_car.get_descriptive_name())
my_new_car.read_odometer()
# Out:
# Audi A4 2014
# This car has 0 miles in it.

# %%
my_new_car.odometer_reading = 23
my_new_car.read_odometer()
# Out:
# This car has 23 miles in it.

# %%
class Car:
    def __init__(self, make, model, year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0

    def get_describe_name(self):
        long_name = f"{self.make} {self.model} {self.year}"
        return long_name.title()

    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odometer(self, mileage):
        if (mileage >= self.odometer_reading):
            self.odometer_reading = mileage
        else:
            print("Your can not roll back an odometer!")

    def increment_odometer(self, miles):
        self.odometer_reading += miles

# %% [markdown]
# ### 继承

# %%
class Electric_car(Car):
    def __init__(self, make, model, year):
        super().__init__(make, model, year)
        self.battery_size = 40

    def desctibe_battery_size(self):
        print(f"This car has a {self.battery_size}-kWh batter.")


electric_cat = Electric_car('Audi', 'A4', 2025)
electric_cat.get_describe_name()
# Out:
# 'Audi A4 2025'

# %%
electric_cat.desctibe_battery_size()
# Out:
# This car has a 40-kWh batter.

# %%
from electric_car import ElectricCar
my_car = Electric_car('Nissan', 'leaf', 2024)
my_car.get_describe_name()
# Out:
# 'Nissan Leaf 2024'

# %%
my_car.desctibe_battery_size()
# Out:
# This car has a 40-kWh batter.

# %%
# 骰子　创建一个Die类，它包含一个名为sides的属性，该属性的默认值为6。
# 编写一个名为roll_die()的方法，它打印位于1和骰子面数之间的随机数。创建一个6面的骰子并掷10次。
from random import randint


class Die:
    def __init__(self, sides=6):
        self.sides = sides

    def roll_die(self):
        return randint(1, self.sides)


my_die = Die(6)
sides_list = []
for i in range(1, 11):
    sides_list.append(my_die.roll_die())
print(sides_list)
# Out:
# [4, 5, 5, 3, 5, 5, 3, 2, 5, 1]
